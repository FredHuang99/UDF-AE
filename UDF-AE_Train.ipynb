# %%
import torch
import torch.nn as nn
from torch.autograd import Variable
import torch.optim as optim
import torch.nn.functional as F
import h5py
import numpy as np

# %%
#data used for training and experiment is stored in hdf5 format
#only tec025 is divided into training set and verification set and others only have 'data_mat'
f = h5py.File('tec025.hdf5','r') 
train_data = np.array(f['train_mat'])
val_data = np.array(f['val_mat'])
#switch the data from signed distance field into unsigned distance field
train_data[train_data<0] = -train_data[train_data<0]
val_data[val_data<0] = -val_data[val_data<0]
#present the shape of traning data
print(train_data[train_data==0].shape)
print(train_data[train_data>0].shape)
print(train_data.shape)
print(val_data[val_data==0].shape)
print(val_data[val_data>0].shape)
print(val_data.shape)
# Out:
# (53394,)
# (15216494,)
# (466, 32, 32, 32)
# (3531,)
# (1503797,)
# (46, 32, 32, 32)

# %%
device = torch.device('cuda:0' if torch.cuda.is_available() else 'cpu')

# %%
class SAE(nn.Module):
    def __init__(self):
        super(SAE,self).__init__()
        self.conv1 = nn.Conv3d(in_channels=1,out_channels=8,kernel_size=2,stride=2,padding=0,bias=False)
        self.conv2 = nn.Conv3d(in_channels=8,out_channels=32,kernel_size=2,stride=2,padding=0,bias=False)
        self.conv3 = nn.Conv3d(in_channels=32,out_channels=64,kernel_size=2,stride=2,padding=0,bias=False)
        self.conv4 = nn.ConvTranspose3d(in_channels=64,out_channels=32,kernel_size=2,stride=2,padding=0,bias=True)
        self.conv5 = nn.ConvTranspose3d(in_channels=32,out_channels=8,kernel_size=2,stride=2,padding=0,bias=True)
        self.conv6 = nn.ConvTranspose3d(in_channels=8,out_channels=1,kernel_size=2,stride=2,padding=0,bias=True)
    def forward(self,x):
        x1 = F.relu(self.conv1(x))
        x1 = F.relu(self.conv2(x1))
        x1 = F.relu(self.conv3(x1))
        x2 = F.relu(self.conv4(x1))
        x2 = F.relu(self.conv5(x2))
        x2 = F.relu(self.conv6(x2))
        return x1,x2

# %%
torch.cuda.empty_cache()

# %%
net=SAE().to(device)
criterion = nn.MSELoss()
optimizer = torch.optim.Adam(net.parameters(),lr = 0.01)

# %%
torch.cuda.empty_cache()

# %%
epoches = 80
batch_size = 4
dataloader = torch.utils.data.DataLoader(dataset = train_data,batch_size = batch_size,shuffle = True,drop_last = False)

# %%
for epoch in range(epoches):
    for i,data in enumerate(dataloader):
        data = data.reshape(-1,1,32,32,32)
        data = data.to(device)
        output1,output2 = net(data)
        optimizer.zero_grad()
        loss = criterion(output2,data)
        loss.backward()
        optimizer.step()
        if i%50==0 :
            print("epoch:",epoch)
            print("i:",i)
            print("Loss:",loss.data.cpu())
# Out:
# epoch: 0
# i: 0
# Loss: tensor(90716.7422)
# epoch: 0
# i: 50
# Loss: tensor(21937.7656)
# epoch: 0
# i: 100
# Loss: tensor(12315.2441)
# epoch: 1
# i: 0
# Loss: tensor(12378.7256)
# epoch: 1
# i: 50
# Loss: tensor(17401.5566)
# epoch: 1
# i: 100
# Loss: tensor(11678.4434)
# epoch: 2
# i: 0
# Loss: tensor(18416.9434)
# epoch: 2
# i: 50
# Loss: tensor(11944.2207)
# epoch: 2
# i: 100
# Loss: tensor(12932.0410)
# epoch: 3
# i: 0
# Loss: tensor(12379.9590)
# epoch: 3
# i: 50
# Loss: tensor(17406.2070)
# epoch: 3
# i: 100
# Loss: tensor(16459.5664)
# epoch: 4
# i: 0
# Loss: tensor(13158.7305)
# epoch: 4
# i: 50
# Loss: tensor(8745.0020)
# epoch: 4
# i: 100
# Loss: tensor(377.9664)
# epoch: 5
# i: 0
# Loss: tensor(183.4705)
# epoch: 5
# i: 50
# Loss: tensor(175.6471)
# epoch: 5
# i: 100
# Loss: tensor(152.7775)
# epoch: 6
# i: 0
# Loss: tensor(138.2201)
# epoch: 6
# i: 50
# Loss: tensor(138.3181)
# epoch: 6
# i: 100
# Loss: tensor(102.9841)
# epoch: 7
# i: 0
# Loss: tensor(146.5344)
# epoch: 7
# i: 50
# Loss: tensor(153.8324)
# epoch: 7
# i: 100
# Loss: tensor(139.4715)
# epoch: 8
# i: 0
# Loss: tensor(72.0358)
# epoch: 8
# i: 50
# Loss: tensor(123.5055)
# epoch: 8
# i: 100
# Loss: tensor(134.1424)
# epoch: 9
# i: 0
# Loss: tensor(300.7780)
# epoch: 9
# i: 50
# Loss: tensor(442.7682)
# epoch: 9
# i: 100
# Loss: tensor(75.5665)
# epoch: 10
# i: 0
# Loss: tensor(1021.2971)
# epoch: 10
# i: 50
# Loss: tensor(476.7944)
# epoch: 10
# i: 100
# Loss: tensor(226.8448)
# epoch: 11
# i: 0
# Loss: tensor(86.8535)
# epoch: 11
# i: 50
# Loss: tensor(60.9331)
# epoch: 11
# i: 100
# Loss: tensor(60.2507)
# epoch: 12
# i: 0
# Loss: tensor(59.5915)
# epoch: 12
# i: 50
# Loss: tensor(125.4925)
# epoch: 12
# i: 100
# Loss: tensor(109.7600)
# epoch: 13
# i: 0
# Loss: tensor(305.8779)
# epoch: 13
# i: 50
# Loss: tensor(54.3648)
# epoch: 13
# i: 100
# Loss: tensor(261.0685)
# epoch: 14
# i: 0
# Loss: tensor(62628.9844)
# epoch: 14
# i: 50
# Loss: tensor(1561.5212)
# epoch: 14
# i: 100
# Loss: tensor(323.5770)
# epoch: 15
# i: 0
# Loss: tensor(271.5560)
# epoch: 15
# i: 50
# Loss: tensor(232.4803)
# epoch: 15
# i: 100
# Loss: tensor(121.8265)
# epoch: 16
# i: 0
# Loss: tensor(112.0410)
# epoch: 16
# i: 50
# Loss: tensor(90.4556)
# epoch: 16
# i: 100
# Loss: tensor(84.4606)
# epoch: 17
# i: 0
# Loss: tensor(59.3898)
# epoch: 17
# i: 50
# Loss: tensor(68.0332)
# epoch: 17
# i: 100
# Loss: tensor(58.1230)
# epoch: 18
# i: 0
# Loss: tensor(60.8504)
# epoch: 18
# i: 50
# Loss: tensor(55.6837)
# epoch: 18
# i: 100
# Loss: tensor(43.2411)
# epoch: 19
# i: 0
# Loss: tensor(44.1854)
# epoch: 19
# i: 50
# Loss: tensor(38.5751)
# epoch: 19
# i: 100
# Loss: tensor(35.6450)
# epoch: 20
# i: 0
# Loss: tensor(44.5128)
# epoch: 20
# i: 50
# Loss: tensor(39.9564)
# epoch: 20
# i: 100
# Loss: tensor(44.6088)
# epoch: 21
# i: 0
# Loss: tensor(41.6837)
# epoch: 21
# i: 50
# Loss: tensor(28.8524)
# epoch: 21
# i: 100
# Loss: tensor(42.6139)
# epoch: 22
# i: 0
# Loss: tensor(41.1139)
# epoch: 22
# i: 50
# Loss: tensor(36.2993)
# epoch: 22
# i: 100
# Loss: tensor(44.9002)
# epoch: 23
# i: 0
# Loss: tensor(33.5933)
# epoch: 23
# i: 50
# Loss: tensor(37.7321)
# epoch: 23
# i: 100
# Loss: tensor(29.6229)
# epoch: 24
# i: 0
# Loss: tensor(30.1185)
# epoch: 24
# i: 50
# Loss: tensor(29.6117)
# epoch: 24
# i: 100
# Loss: tensor(31.9137)
# epoch: 25
# i: 0
# Loss: tensor(32.9941)
# epoch: 25
# i: 50
# Loss: tensor(31.2229)
# epoch: 25
# i: 100
# Loss: tensor(88.7394)
# epoch: 26
# i: 0
# Loss: tensor(81.2160)
# epoch: 26
# i: 50
# Loss: tensor(31.6068)
# epoch: 26
# i: 100
# Loss: tensor(148.9570)
# epoch: 27
# i: 0
# Loss: tensor(188.6226)
# epoch: 27
# i: 50
# Loss: tensor(41.4926)
# epoch: 27
# i: 100
# Loss: tensor(928.2858)
# epoch: 28
# i: 0
# Loss: tensor(328.9753)
# epoch: 28
# i: 50
# Loss: tensor(32.6755)
# epoch: 28
# i: 100
# Loss: tensor(57.0615)
# epoch: 29
# i: 0
# Loss: tensor(46.3308)
# epoch: 29
# i: 50
# Loss: tensor(30.6169)
# epoch: 29
# i: 100
# Loss: tensor(22.8769)
# epoch: 30
# i: 0
# Loss: tensor(28.2803)
# epoch: 30
# i: 50
# Loss: tensor(31.0861)
# epoch: 30
# i: 100
# Loss: tensor(24.3134)
# epoch: 31
# i: 0
# Loss: tensor(31.8176)
# epoch: 31
# i: 50
# Loss: tensor(20.9644)
# epoch: 31
# i: 100
# Loss: tensor(19.5699)
# epoch: 32
# i: 0
# Loss: tensor(19.8462)
# epoch: 32
# i: 50
# Loss: tensor(30.7930)
# epoch: 32
# i: 100
# Loss: tensor(25.2434)
# epoch: 33
# i: 0
# Loss: tensor(35.2888)
# epoch: 33
# i: 50
# Loss: tensor(21.4467)
# epoch: 33
# i: 100
# Loss: tensor(27.6264)
# epoch: 34
# i: 0
# Loss: tensor(22.1090)
# epoch: 34
# i: 50
# Loss: tensor(22.5009)
# epoch: 34
# i: 100
# Loss: tensor(65.4811)
# epoch: 35
# i: 0
# Loss: tensor(28.9192)
# epoch: 35
# i: 50
# Loss: tensor(672.5287)
# epoch: 35
# i: 100
# Loss: tensor(2218.5564)
# epoch: 36
# i: 0
# Loss: tensor(2268.6775)
# epoch: 36
# i: 50
# Loss: tensor(176.7909)
# epoch: 36
# i: 100
# Loss: tensor(50.7384)
# epoch: 37
# i: 0
# Loss: tensor(50.6917)
# epoch: 37
# i: 50
# Loss: tensor(38.0751)
# epoch: 37
# i: 100
# Loss: tensor(42.1256)
# epoch: 38
# i: 0
# Loss: tensor(38.5486)
# epoch: 38
# i: 50
# Loss: tensor(37.1135)
# epoch: 38
# i: 100
# Loss: tensor(34.3260)
# epoch: 39
# i: 0
# Loss: tensor(26.7237)
# epoch: 39
# i: 50
# Loss: tensor(20.2640)
# epoch: 39
# i: 100
# Loss: tensor(17.7928)
# epoch: 40
# i: 0
# Loss: tensor(27.5484)
# epoch: 40
# i: 50
# Loss: tensor(22.6814)
# epoch: 40
# i: 100
# Loss: tensor(21.8102)
# epoch: 41
# i: 0
# Loss: tensor(17.7605)
# epoch: 41
# i: 50
# Loss: tensor(22.1121)
# epoch: 41
# i: 100
# Loss: tensor(20.3941)
# epoch: 42
# i: 0
# Loss: tensor(18.9973)
# epoch: 42
# i: 50
# Loss: tensor(22.0116)
# epoch: 42
# i: 100
# Loss: tensor(12.6763)
# epoch: 43
# i: 0
# Loss: tensor(24.2279)
# epoch: 43
# i: 50
# Loss: tensor(15.5459)
# epoch: 43
# i: 100
# Loss: tensor(18.3120)
# epoch: 44
# i: 0
# Loss: tensor(21.5218)
# epoch: 44
# i: 50
# Loss: tensor(24.7760)
# epoch: 44
# i: 100
# Loss: tensor(22.3826)
# epoch: 45
# i: 0
# Loss: tensor(20.0402)
# epoch: 45
# i: 50
# Loss: tensor(18.9880)
# epoch: 45
# i: 100
# Loss: tensor(18.5234)
# epoch: 46
# i: 0
# Loss: tensor(20.4120)
# epoch: 46
# i: 50
# Loss: tensor(28.2001)
# epoch: 46
# i: 100
# Loss: tensor(23.0850)
# epoch: 47
# i: 0
# Loss: tensor(21.7830)
# epoch: 47
# i: 50
# Loss: tensor(17.6835)
# epoch: 47
# i: 100
# Loss: tensor(16.5733)
# epoch: 48
# i: 0
# Loss: tensor(24.4207)
# epoch: 48
# i: 50
# Loss: tensor(162.6979)
# epoch: 48
# i: 100
# Loss: tensor(46.3345)
# epoch: 49
# i: 0
# Loss: tensor(18.5564)
# epoch: 49
# i: 50
# Loss: tensor(17.0328)
# epoch: 49
# i: 100
# Loss: tensor(17.4317)
# epoch: 50
# i: 0
# Loss: tensor(16.4860)
# epoch: 50
# i: 50
# Loss: tensor(17.1627)
# epoch: 50
# i: 100
# Loss: tensor(12.6797)
# epoch: 51
# i: 0
# Loss: tensor(137.2078)
# epoch: 51
# i: 50
# Loss: tensor(682.4033)
# epoch: 51
# i: 100
# Loss: tensor(140.8098)
# epoch: 52
# i: 0
# Loss: tensor(98.3341)
# epoch: 52
# i: 50
# Loss: tensor(114.3166)
# epoch: 52
# i: 100
# Loss: tensor(77.8008)
# epoch: 53
# i: 0
# Loss: tensor(52.6162)
# epoch: 53
# i: 50
# Loss: tensor(79.8650)
# epoch: 53
# i: 100
# Loss: tensor(101.3102)
# epoch: 54
# i: 0
# Loss: tensor(65.2382)
# epoch: 54
# i: 50
# Loss: tensor(75.8903)
# epoch: 54
# i: 100
# Loss: tensor(141.2449)
# epoch: 55
# i: 0
# Loss: tensor(48.3434)
# epoch: 55
# i: 50
# Loss: tensor(65.0443)
# epoch: 55
# i: 100
# Loss: tensor(63.8451)
# epoch: 56
# i: 0
# Loss: tensor(56.4254)
# epoch: 56
# i: 50
# Loss: tensor(48.1040)
# epoch: 56
# i: 100
# Loss: tensor(61.2392)
# epoch: 57
# i: 0
# Loss: tensor(194.9664)
# epoch: 57
# i: 50
# Loss: tensor(65.4020)
# epoch: 57
# i: 100
# Loss: tensor(52.8972)
# epoch: 58
# i: 0
# Loss: tensor(57.8829)
# epoch: 58
# i: 50
# Loss: tensor(51.7454)
# epoch: 58
# i: 100
# Loss: tensor(47.2213)
# epoch: 59
# i: 0
# Loss: tensor(53.5967)
# epoch: 59
# i: 50
# Loss: tensor(81.2058)
# epoch: 59
# i: 100
# Loss: tensor(39.5543)
# epoch: 60
# i: 0
# Loss: tensor(103.4393)
# epoch: 60
# i: 50
# Loss: tensor(103.4689)
# epoch: 60
# i: 100
# Loss: tensor(65.2731)
# epoch: 61
# i: 0
# Loss: tensor(50.1897)
# epoch: 61
# i: 50
# Loss: tensor(48.4676)
# epoch: 61
# i: 100
# Loss: tensor(50.5579)
# epoch: 62
# i: 0
# Loss: tensor(38.3273)
# epoch: 62
# i: 50
# Loss: tensor(46.9141)
# epoch: 62
# i: 100
# Loss: tensor(42.1343)
# epoch: 63
# i: 0
# Loss: tensor(36.7146)
# epoch: 63
# i: 50
# Loss: tensor(49.6543)
# epoch: 63
# i: 100
# Loss: tensor(49.2617)
# epoch: 64
# i: 0
# Loss: tensor(66.9381)
# epoch: 64
# i: 50
# Loss: tensor(48.6043)
# epoch: 64
# i: 100
# Loss: tensor(32.5002)
# epoch: 65
# i: 0
# Loss: tensor(39.1551)
# epoch: 65
# i: 50
# Loss: tensor(45.7378)
# epoch: 65
# i: 100
# Loss: tensor(31.6503)
# epoch: 66
# i: 0
# Loss: tensor(36.5965)
# epoch: 66
# i: 50
# Loss: tensor(295.3330)
# epoch: 66
# i: 100
# Loss: tensor(976.3912)
# epoch: 67
# i: 0
# Loss: tensor(586.7880)
# epoch: 67
# i: 50
# Loss: tensor(54.3546)
# epoch: 67
# i: 100
# Loss: tensor(47.7142)
# epoch: 68
# i: 0
# Loss: tensor(33.0843)
# epoch: 68
# i: 50
# Loss: tensor(37.5544)
# epoch: 68
# i: 100
# Loss: tensor(30.8680)
# epoch: 69
# i: 0
# Loss: tensor(40.5387)
# epoch: 69
# i: 50
# Loss: tensor(32.2973)
# epoch: 69
# i: 100
# Loss: tensor(34.4338)
# epoch: 70
# i: 0
# Loss: tensor(38.6336)
# epoch: 70
# i: 50
# Loss: tensor(28.9922)
# epoch: 70
# i: 100
# Loss: tensor(26.3843)
# epoch: 71
# i: 0
# Loss: tensor(30.7197)
# epoch: 71
# i: 50
# Loss: tensor(30.3248)
# epoch: 71
# i: 100
# Loss: tensor(30.8874)
# epoch: 72
# i: 0
# Loss: tensor(21.0887)
# epoch: 72
# i: 50
# Loss: tensor(24.3939)
# epoch: 72
# i: 100
# Loss: tensor(22.5809)
# epoch: 73
# i: 0
# Loss: tensor(24.5769)
# epoch: 73
# i: 50
# Loss: tensor(27.5915)
# epoch: 73
# i: 100
# Loss: tensor(26.0879)
# epoch: 74
# i: 0
# Loss: tensor(24.9127)
# epoch: 74
# i: 50
# Loss: tensor(25.6784)
# epoch: 74
# i: 100
# Loss: tensor(22.0150)
# epoch: 75
# i: 0
# Loss: tensor(18.4352)
# epoch: 75
# i: 50
# Loss: tensor(21.4006)
# epoch: 75
# i: 100
# Loss: tensor(25.1903)
# epoch: 76
# i: 0
# Loss: tensor(21.9645)
# epoch: 76
# i: 50
# Loss: tensor(95.2705)
# epoch: 76
# i: 100
# Loss: tensor(31.8135)
# epoch: 77
# i: 0
# Loss: tensor(160.4260)
# epoch: 77
# i: 50
# Loss: tensor(36.5404)
# epoch: 77
# i: 100
# Loss: tensor(22.3877)
# epoch: 78
# i: 0
# Loss: tensor(24.7602)
# epoch: 78
# i: 50
# Loss: tensor(19.5606)
# epoch: 78
# i: 100
# Loss: tensor(25.6375)
# epoch: 79
# i: 0
# Loss: tensor(61.8389)
# epoch: 79
# i: 50
# Loss: tensor(21.5389)
# epoch: 79
# i: 100
# Loss: tensor(23.8867)

# %%
torch.save(net.state_dict(), 'UDF-AE.pkl')
# Out:
# <All keys matched successfully>
